# %% [markdown]
# # Random Forest Classifier Algorithm
# **Rastgele Ağaç Sınıflandırma Algoritması**
#
# *oemerfaruk.dev youtube*

# %% [markdown]
# ### Veriyi Dahil Etme

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
x = iris.data
y = iris.target

features = load_iris().feature_names
classes = load_iris().target_names

# %% [markdown]
# ### Eğitim ve Test Verisini Bölme

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Modeli Eğitme ve Tahmin

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=5)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_predict)
print(score)
# Out:
# 1.0

# %% [markdown]
# ### Grafik

# %%
from sklearn.tree import plot_tree
from matplotlib import pyplot as plt

# %%
for i, tree in enumerate(model.estimators_):
    plt.figure(figsize=(8, 5))
    plot_tree(tree, feature_names=features, class_names=classes, filled=True)
    plt.title(f"Ağaç {i+1}")
    plt.show()

# %%
importances = model.feature_importances_
plt.bar(features, importances)
plt.show()
